# %% [markdown]
# # Deep Learning Project
# ## Team:
# ###   - Akshay P M          AM.EN.U4CSE20006
# ###   - Ritik Kumar Singh   AM.EN.U4CSE20061
# ###   - T Vishnu Sandeep    AM.EN.U4CSE20073
# ###   - Patel RajKumar P    AM.EN.U4CSE20349
#
# ## Motivation:
# ###  - Create a Custom and efficient CNN Model and hyperparameter tuning ALexnet to classify the various classes present in the Vehicle dataset
# #### Two classes Vehicles or Non Vehicles

# %% [markdown]
# #For creating split in images
# import splitfolders
# splitfolders.ratio(input="E:\Codes\Deep Learning CV\Project\Dataset\DPCV_Project 2",
#                    output="E:\Codes\Deep Learning CV\Project\Dataset\proj_dataset 2",
#                    seed=1337, ratio=(.8, 0.1,0.1),group_prefix=None,move=False)

# %%
import os
import cv2
from cv2 import imread, resize
__all__ = [imread, resize]
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,datasets,models
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
#### Fixing the image sizes
img_size=32

# %%
# importing Dataset
vehicle_dir = "E:/Codes/Deep Learning CV/Project/Dataset/DPCV_Project/vehicles"
nonvehicle_dir = "E:/Codes/Deep Learning CV/Project/Dataset/DPCV_Project/non-vehicles"
vehicle = os.listdir(vehicle_dir)
non_vehicle = os.listdir(nonvehicle_dir)

# %%
# loading images and labels into np array
imgs = []
labels = []
import tqdm

for i in tqdm.tqdm(vehicle):
    img = cv2.imread(vehicle_dir+'/'+ i)
    img = cv2.resize(img,(img_size,img_size))
    imgs.append(img)
    labels.append(1)

for i in tqdm.tqdm(non_vehicle):
    img = cv2.imread(nonvehicle_dir+'/'+ i)
    img = cv2.resize(img,(img_size,img_size))
    imgs.append(img)
    labels.append(0)
# Out:
# 100%|██████████| 8792/8792 [00:01<00:00, 5765.31it/s]
# 100%|██████████| 8968/8968 [00:01<00:00, 6102.41it/s]

# %%
#### Getting Image dimensions
imgs = np.array(imgs)
labels = np.array(labels)
imgs.shape,labels.shape
# Out:
# ((17760, 32, 32, 3), (17760,))

# %%
# splitting into train and test set
train_imgs, test_imgs, train_labels, test_labels = train_test_split(imgs, labels, test_size=0.2, random_state=42)

# %%
from matplotlib import pyplot as plt
plt.imshow(imgs[0])
plt.show()
print(labels[0])
# Out:
# 1

# %%
#### Custom CNN Implementation
def build_model_Custom():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_size,img_size, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.001),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
                  metrics=['accuracy'])
    return model

# %%
model = build_model_Custom()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 64)                65600
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 121,985
# Trainable params: 121,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Implement callback function to stop training
# when accuracy reaches e.g. ACCURACY_THRESHOLD = 0.97
ACCURACY_THRESHOLD = 0.97
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs["accuracy"]
        if accuracy > ACCURACY_THRESHOLD:
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
            self.model.stop_training = True

callback = myCallback()

# %%
history = model.fit(train_imgs, train_labels, epochs=20,validation_data=(test_imgs, test_labels),batch_size=64,callbacks=callback)
# Out:
# Epoch 1/20
# 222/222 [==============================] - 23s 103ms/step - loss: 0.5134 - accuracy: 0.8500 - val_loss: 0.2519 - val_accuracy: 0.8941
# Epoch 2/20
# 222/222 [==============================] - 21s 95ms/step - loss: 0.2062 - accuracy: 0.9173 - val_loss: 0.1717 - val_accuracy: 0.9347
# Epoch 3/20
# 222/222 [==============================] - 22s 97ms/step - loss: 0.1666 - accuracy: 0.9369 - val_loss: 0.1711 - val_accuracy: 0.9344
# Epoch 4/20
# 222/222 [==============================] - 22s 99ms/step - loss: 0.1351 - accuracy: 0.9522 - val_loss: 0.1245 - val_accuracy: 0.9603
# Epoch 5/20
# 222/222 [==============================] - 22s 100ms/step - loss: 0.1164 - accuracy: 0.9583 - val_loss: 0.1103 - val_accuracy: 0.9620
# Epoch 6/20
# 222/222 [==============================] - 21s 94ms/step - loss: 0.1003 - accuracy: 0.9664 - val_loss: 0.1102 - val_accuracy: 0.9575
# Epoch 7/20
# 222/222 [==============================] - 22s 98ms/step - loss: 0.0915 - accuracy: 0.9690 - val_loss: 0.1576 - val_accuracy: 0.9448
# Epoch 8/20
# 222/222 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9723
# Reached 97.00% accuracy, so stopping training!!
# 222/222 [==============================] - 23s 103ms/step - loss: 0.0811 - accuracy: 0.9723 - val_loss: 0.0927 - val_accuracy: 0.9682

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(test_imgs,  test_labels, verbose=2)

# Saving the model
# model.save('Project_Vehicle.h5')

# Plotting the accuracy and loss
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
# legend on top right
plt.legend(loc='upper right')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 2])
# legend on top right
plt.legend(loc='upper right')
# Out:
# 111/111 - 1s - loss: 0.0927 - accuracy: 0.9682 - 781ms/epoch - 7ms/step

# %% [markdown]
# keras.backend.clear_session()

# %%
#### Defining Function for printing an output
def is_vehicle(modelx, img):
    pred = modelx.predict(img)
    res = pred > 0.5
    if res:
        print("Its an automobile (%.5f%%)"%(pred*100))
    else:
        print("Its not an automobile (%.5f%%)"%((1-pred)*100))

# %%
# getting test image location
img_org = cv2.imread("E:/Codes/Deep Learning CV/Project/Dataset/vehicle_images/1633889235234_BMW i8 Protonic 2017 for sale.jpg")
img0 = cv2.resize(img_org,(img_size,img_size))
img=img0.reshape(1,32,32,3)

# %%
# display test image
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(1,2,1)
plt.imshow(img_org)
fig.add_subplot(1,2,2)
plt.imshow(img0)
plt.show()

# %%
is_vehicle(model,img)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Its an automobile

# %% [markdown]
# #### Custom Alexnet Implementation
# def build_model_AlexNet():
#     model = models.Sequential()
#     model.add(layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)))
#     model.add(layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
#     model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
#     model.add(layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
#     model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
#     model.add(layers.Conv2D(filters=384, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"))
#     model.add(layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"))
#     model.add(layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
#     model.add(layers.Flatten())
#     model.add(layers.Dense(4096, activation='relu'))
#     model.add(layers.Dense(4096, activation='relu'))
#     model.add(layers.Dense(10, activation='softmax'))
#
#     model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.001),
#                   loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                   metrics=['accuracy'])
#     return model

# %%
##### Hyperparameter tuning the model (AlexNet)
def build_model_0(hp):
    model = models.Sequential()
    model.add(layers.Conv2D(hp.Int('Conv1',min_value=32, max_value=128), (3, 3), activation='relu', input_shape=(img_size,img_size, 3)))
    model.add(layers.MaxPool2D((3,3),(2,2)))

    kernel1 = hp.Int('ker1',min_value=4, max_value=6)
    model.add(layers.Conv2D(hp.Int('Conv2',min_value=32, max_value=96), (kernel1,kernel1), (1,1), activation='relu', padding="same"))
    model.add(layers.MaxPool2D((3,3), (2,2)))

    kernel2 = hp.Int('ker2',min_value=2, max_value=4)
    model.add(layers.Conv2D(hp.Int('Conv3',min_value=32, max_value=96),(kernel2,kernel2),(1,1), activation='relu', padding="same"))
    model.add(layers.Conv2D(hp.Int('Conv4',min_value=32, max_value=96),(1,1),(1,1), activation='relu', padding="same"))
    model.add(layers.Conv2D(hp.Int('Conv5',min_value=32, max_value=96), (1,1), (1,1), activation='relu', padding="same"))
    model.add(layers.MaxPool2D((3,3),(2,2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(units=hp.Int('Dense1',min_value=32, max_value=512), activation='relu'))
    model.add(layers.Dense(units=hp.Int('Dense2',min_value=32, max_value=512), activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer=tf.optimizers.SGD(learning_rate=0.001),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
                  metrics=['accuracy'])
    return model

# %%
tuner=RandomSearch(build_model_0,objective='val_accuracy',max_trials=5,directory='output',project_name="Vehicle classification")
# Out:
# INFO:tensorflow:Reloading Oracle from existing project output\Vehicle classification\oracle.json

# %%
tuner.search(train_imgs,train_labels,epochs=3,validation_split=0.1)
# Out:
# Trial 5 Complete [00h 03m 18s]
# val_accuracy: 0.9472202658653259
#
# Best val_accuracy So Far: 0.9634060263633728
# Total elapsed time: 00h 17m 08s
# INFO:tensorflow:Oracle triggered exit

# %%
op_model=tuner.get_best_models(num_models=1)[0]

# %%
op_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 48)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 81)        140049
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 81)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 48)          62256
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 92)          4508
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 34)          3162
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 34)         0
#  2D)
#
#  flatten (Flatten)           (None, 136)               0
#
#  dense (Dense)               (None, 83)                11371
#
#  dense_1 (Dense)             (None, 176)               14784
#
#  dense_2 (Dense)             (None, 1)                 177
#
# =================================================================
# Total params: 237,651
# Trainable params: 237,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Implement callback function to stop training
# when accuracy reaches e.g. ACCURACY_THRESHOLD = 0.99
ACCURACY_THRESHOLD = 0.99
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        accuracy = logs["accuracy"]
        if accuracy > ACCURACY_THRESHOLD:
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
            self.model.stop_training = True

callback = myCallback()

# %%
op_model.fit(train_imgs, train_labels, epochs=20, validation_split=0.1, initial_epoch=3,callbacks=callback)
# Out:
# Epoch 4/20
# 400/400 [==============================] - 72s 179ms/step - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.0771 - val_accuracy: 0.9740
# Epoch 5/20
# 400/400 [==============================] - 72s 180ms/step - loss: 0.0742 - accuracy: 0.9747 - val_loss: 0.0811 - val_accuracy: 0.9719
# Epoch 6/20
# 400/400 [==============================] - 72s 180ms/step - loss: 0.0577 - accuracy: 0.9809 - val_loss: 0.0574 - val_accuracy: 0.9810
# Epoch 7/20
# 400/400 [==============================] - 72s 181ms/step - loss: 0.0490 - accuracy: 0.9840 - val_loss: 0.0527 - val_accuracy: 0.9803
# Epoch 8/20
# 400/400 [==============================] - 73s 182ms/step - loss: 0.0412 - accuracy: 0.9859 - val_loss: 0.0478 - val_accuracy: 0.9852
# Epoch 9/20
# 400/400 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9914
# Reached 99.00% accuracy, so stopping training!!
# 400/400 [==============================] - 73s 182ms/step - loss: 0.0304 - accuracy: 0.9914 - val_loss: 0.0556 - val_accuracy: 0.9859

# %%
#### Testing with garbage image
img_org = cv2.imread("E:\Codes\Deep Learning CV\Project\Dataset\DPCV_Project\\non-vehicles\extra15.png")
img0 = cv2.resize(img_org,(img_size,img_size))
img=img0.reshape(1,32,32,3)

# %%
# display test image
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(1,2,1)
plt.imshow(img_org)
fig.add_subplot(1,2,2)
plt.imshow(img0)
plt.show()

# %%
is_vehicle(op_model,img)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Its not an automobile (99.99535%)

# %%
#### Testing with Car image
img_org = cv2.imread("E:/Codes/Deep Learning CV/Project/Dataset/vehicle_images/1633889235234_BMW i8 Protonic 2017 for sale.jpg")
img0 = cv2.resize(img_org,(img_size,img_size))
img=img0.reshape(1,32,32,3)

# %%
# display test image
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(1,2,1)
plt.imshow(img_org)
fig.add_subplot(1,2,2)
plt.imshow(img0)
plt.show()

# %%
is_vehicle(op_model,img)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Its an automobile (99.99998%)
